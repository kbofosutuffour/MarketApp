# %%
import pandas as pd
import numpy as np

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.2.2-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 1.7 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      |████████████████████████████████| 505 kB 1.7 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      |████████████████████████████████| 345 kB 1.3 MB/s eta 0:00:01
# Collecting numpy>=1.22.4
#   Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Installing collected packages: tzdata, pytz, numpy, pandas
#   WARNING: The script f2py is installed in '/Users/janerhee/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed numpy-1.26.4 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp39-cp39-macosx_11_0_arm64.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 1.6 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.51.0-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.21 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.26.4)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pillow>=8
#   Downloading pillow-10.3.0-cp39-cp39-macosx_11_0_arm64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 2.0 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 1.6 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.8.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp39-cp39-macosx_11_0_arm64.whl (244 kB)
#      |████████████████████████████████| 244 kB 1.5 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl (66 kB)
#      |████████████████████████████████| 66 kB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Users/janerhee/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 importlib-resources-6.4.0 kiwisolver-1.4.5 matplotlib-3.8.4 pillow-10.3.0 pyparsing-3.1.2
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: pandas>=1.2 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: cycler>=0.10 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pillow>=8 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.ticker as ticker
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/janerhee/marketapp/MarketApp/NLP/countries_amazon.csv')

# %%
df
# Out:
#                                 Category  \
# 0                   Skin Care | Lee Posh
# 1                  Skin Care | SLB Works
# 2                    Skin Care | Generic
# 3                    Skin Care | Generic
# 4      Grocery & Gourmet Foods | Harveys
# ...                                  ...
# 27463                 Skin Care | Laikou
# 27464         Bath & Shower | Dermasolve
# 27465          Skin Care | Pure Organics
# 27466                 Skin Care | YASHUS
# 27467                   Skin Care | Slss
#
#                                            Product Title  \
# 0       Lee posh Lactic Acid 60% Anti ageing Pigmenta...
# 1       Branded SLB Works New 1.5mm Titanium 1200 nee...
# 2       Generic 1 Pc brand snail eye cream remove dar...
# 3       Generic Anti Snoring Snore Stopper Sleep Apne...
# 4       Harveys Crunchy & Creame Gourmet Delicacies C...
# ...                                                  ...
# 27463   New Day Creams & Moisturizers Pure Nature Soo...
# 27464             Dermasolve Psoriasis Body Wash 8.0 Oz
# 27465   Pure Organics Skin Lightening Mild Face Scrub...
# 27466   Yashus Moisturizing Anti-aging Gold Collagen ...
# 27467   Slss Anti Wrinkle Organic Hyaluronic Acid Vit...
#
#                                      Product Description    Price Conditions
# 0      PROFESSIONAL GRADE Face Peel: this peel stimul...   799.00        New
# 1      Item name: 1.5mm titanium 1200 needles microne...  2040.00  Very good
# 2      Use: eye, item type: cream, net wt: 20g, gzzz:...  1042.00        New
# 3      Prevent the tongue from dropping backward or b...  1399.00        Bad
# 4      Harvey's wafer Cream Wafer 110g. Made in Country3   570.00        Bad
# ...                                                  ...      ...        ...
# 27463  Use: Face, Item Type: Cream, Ingredient: Aloe ...  1004.00       Good
# 27464  Use before showering to help soften the scales...  4294.00        Bad
# 27465  For a smooth & Flawless complexion this scrub ...   224.00   Very bad
# 27466  Gold eye mask is suitable for people: Eye patt...  1050.00        New
# 27467  With 2.5% active Retinol, Hyaluronic Acid, Vit...  2134.00        Bad
#
# [27468 rows x 5 columns]

# %%
df['Product Title']
# Out:
# 0         Lee posh Lactic Acid 60% Anti ageing Pigmenta...
# 1         Branded SLB Works New 1.5mm Titanium 1200 nee...
# 2         Generic 1 Pc brand snail eye cream remove dar...
# 3         Generic Anti Snoring Snore Stopper Sleep Apne...
# 4         Harveys Crunchy & Creame Gourmet Delicacies C...
#                                ...
# 27463     New Day Creams & Moisturizers Pure Nature Soo...
# 27464               Dermasolve Psoriasis Body Wash 8.0 Oz
# 27465     Pure Organics Skin Lightening Mild Face Scrub...
# 27466     Yashus Moisturizing Anti-aging Gold Collagen ...
# 27467     Slss Anti Wrinkle Organic Hyaluronic Acid Vit...
# Name: Product Title, Length: 27468, dtype: object

# %%
df['Product Title'].isnull().sum()
# Out:
# 0

# %%
df['Product Description'].isnull().sum()
# Out:
# 0

# %%
df.dropna(subset=['Product Description'], inplace=True)

# %%
df.columns
# Out:
# Index(['Category', 'Product Title', 'Product Description', 'Price',
#        'Conditions'],
#       dtype='object')

# %%
df_copy=df.copy()
df_copy
# Out:
#                                 Category  \
# 0                   Skin Care | Lee Posh
# 1                  Skin Care | SLB Works
# 2                    Skin Care | Generic
# 3                    Skin Care | Generic
# 4      Grocery & Gourmet Foods | Harveys
# ...                                  ...
# 27463                 Skin Care | Laikou
# 27464         Bath & Shower | Dermasolve
# 27465          Skin Care | Pure Organics
# 27466                 Skin Care | YASHUS
# 27467                   Skin Care | Slss
#
#                                            Product Title  \
# 0       Lee posh Lactic Acid 60% Anti ageing Pigmenta...
# 1       Branded SLB Works New 1.5mm Titanium 1200 nee...
# 2       Generic 1 Pc brand snail eye cream remove dar...
# 3       Generic Anti Snoring Snore Stopper Sleep Apne...
# 4       Harveys Crunchy & Creame Gourmet Delicacies C...
# ...                                                  ...
# 27463   New Day Creams & Moisturizers Pure Nature Soo...
# 27464             Dermasolve Psoriasis Body Wash 8.0 Oz
# 27465   Pure Organics Skin Lightening Mild Face Scrub...
# 27466   Yashus Moisturizing Anti-aging Gold Collagen ...
# 27467   Slss Anti Wrinkle Organic Hyaluronic Acid Vit...
#
#                                      Product Description    Price Conditions
# 0      PROFESSIONAL GRADE Face Peel: this peel stimul...   799.00        New
# 1      Item name: 1.5mm titanium 1200 needles microne...  2040.00  Very good
# 2      Use: eye, item type: cream, net wt: 20g, gzzz:...  1042.00        New
# 3      Prevent the tongue from dropping backward or b...  1399.00        Bad
# 4      Harvey's wafer Cream Wafer 110g. Made in Country3   570.00        Bad
# ...                                                  ...      ...        ...
# 27463  Use: Face, Item Type: Cream, Ingredient: Aloe ...  1004.00       Good
# 27464  Use before showering to help soften the scales...  4294.00        Bad
# 27465  For a smooth & Flawless complexion this scrub ...   224.00   Very bad
# 27466  Gold eye mask is suitable for people: Eye patt...  1050.00        New
# 27467  With 2.5% active Retinol, Hyaluronic Acid, Vit...  2134.00        Bad
#
# [27468 rows x 5 columns]

# %%
df_copy['Category'] = df_copy['Category'].str.split(' | ').str[0]

df_copy
# Out:
#       Category                                      Product Title  \
# 0         Skin   Lee posh Lactic Acid 60% Anti ageing Pigmenta...
# 1         Skin   Branded SLB Works New 1.5mm Titanium 1200 nee...
# 2         Skin   Generic 1 Pc brand snail eye cream remove dar...
# 3         Skin   Generic Anti Snoring Snore Stopper Sleep Apne...
# 4      Grocery   Harveys Crunchy & Creame Gourmet Delicacies C...
# ...        ...                                                ...
# 27463     Skin   New Day Creams & Moisturizers Pure Nature Soo...
# 27464     Bath             Dermasolve Psoriasis Body Wash 8.0 Oz
# 27465     Skin   Pure Organics Skin Lightening Mild Face Scrub...
# 27466     Skin   Yashus Moisturizing Anti-aging Gold Collagen ...
# 27467     Skin   Slss Anti Wrinkle Organic Hyaluronic Acid Vit...
#
#                                      Product Description    Price Conditions
# 0      PROFESSIONAL GRADE Face Peel: this peel stimul...   799.00        New
# 1      Item name: 1.5mm titanium 1200 needles microne...  2040.00  Very good
# 2      Use: eye, item type: cream, net wt: 20g, gzzz:...  1042.00        New
# 3      Prevent the tongue from dropping backward or b...  1399.00        Bad
# 4      Harvey's wafer Cream Wafer 110g. Made in Country3   570.00        Bad
# ...                                                  ...      ...        ...
# 27463  Use: Face, Item Type: Cream, Ingredient: Aloe ...  1004.00       Good
# 27464  Use before showering to help soften the scales...  4294.00        Bad
# 27465  For a smooth & Flawless complexion this scrub ...   224.00   Very bad
# 27466  Gold eye mask is suitable for people: Eye patt...  1050.00        New
# 27467  With 2.5% active Retinol, Hyaluronic Acid, Vit...  2134.00        Bad
#
# [27468 rows x 5 columns]

# %%
product_counts = df_copy['Product Title'].value_counts()

print(product_counts)
# Out:
# Product Title
# Xplus Bath Loofah(Pack of 3)                                                                                                                                                       39
# Bogatchi Chocolate Gift Box, Happy Diwali Chocolate, Diwali Chocolate Gifts, Diwali Chocolate Gift, Diwali Chocolate Bar, Diwali Gifts, 15 Pieces                                  16
# Xplus Bath Loofah                                                                                                                                                                  11
# Midiron Happy Raksha Bandhan Return Gift for Sister with Printed Ceramic Mug and 2 Chocolate Bar                                                                                    8
# CANDYCORNER "Happy Rakshabandhan " ( 9 CHOCOLATE BOX ) - with Love You Bhai | rakshabandhan gift for brother | rakhi gift for sister | gift for rakshabandhan | gift for rakhi      5
#                                                                                                                                                                                    ..
# Chinatera S Contour Face Cream Makeup Concealer Palette With Makeup Brushes By Free Size Black+Blue                                                                                 1
# Fashlady Russian Federation: LANBENA Blackhead Remover Nose Mask T Zone Care Pore Shrinking Strip Peeling Acne Treatment Deep Cleansing With 60pcs Paper                            1
# HAMD Essence Seductive Body Spray - 200ml Body Spray - For Men (200 ml)                                                                                                             1
# Ubervia Pack of 1 Natural Rose Quartz Facial Massage RollerFacial Massager Anti-aging Skin Lift Tools Face Lose weight Beauty Care Machine                                          1
# Slss Anti Wrinkle Organic Hyaluronic Acid Vitamin E and Green Tea Anti-aging Whitening Cream                                                                                        1
# Name: count, Length: 27122, dtype: int64

# %%
# conditions = ['very good', 'good', 'slightly used', 'brand new', 'pre-owned',' ']
# random_conditions = np.random.choice(conditions, size=len(df))
# df['Product Title'] = df['Product Title'] + " - " + random_conditions
# print(df.head())

# %%
df
# Out:
#                                 Category  \
# 0                   Skin Care | Lee Posh
# 1                  Skin Care | SLB Works
# 2                    Skin Care | Generic
# 3                    Skin Care | Generic
# 4      Grocery & Gourmet Foods | Harveys
# ...                                  ...
# 27463                 Skin Care | Laikou
# 27464         Bath & Shower | Dermasolve
# 27465          Skin Care | Pure Organics
# 27466                 Skin Care | YASHUS
# 27467                   Skin Care | Slss
#
#                                            Product Title  \
# 0       Lee posh Lactic Acid 60% Anti ageing Pigmenta...
# 1       Branded SLB Works New 1.5mm Titanium 1200 nee...
# 2       Generic 1 Pc brand snail eye cream remove dar...
# 3       Generic Anti Snoring Snore Stopper Sleep Apne...
# 4       Harveys Crunchy & Creame Gourmet Delicacies C...
# ...                                                  ...
# 27463   New Day Creams & Moisturizers Pure Nature Soo...
# 27464             Dermasolve Psoriasis Body Wash 8.0 Oz
# 27465   Pure Organics Skin Lightening Mild Face Scrub...
# 27466   Yashus Moisturizing Anti-aging Gold Collagen ...
# 27467   Slss Anti Wrinkle Organic Hyaluronic Acid Vit...
#
#                                      Product Description    Price Conditions
# 0      PROFESSIONAL GRADE Face Peel: this peel stimul...   799.00        New
# 1      Item name: 1.5mm titanium 1200 needles microne...  2040.00  Very good
# 2      Use: eye, item type: cream, net wt: 20g, gzzz:...  1042.00        New
# 3      Prevent the tongue from dropping backward or b...  1399.00        Bad
# 4      Harvey's wafer Cream Wafer 110g. Made in Country3   570.00        Bad
# ...                                                  ...      ...        ...
# 27463  Use: Face, Item Type: Cream, Ingredient: Aloe ...  1004.00       Good
# 27464  Use before showering to help soften the scales...  4294.00        Bad
# 27465  For a smooth & Flawless complexion this scrub ...   224.00   Very bad
# 27466  Gold eye mask is suitable for people: Eye patt...  1050.00        New
# 27467  With 2.5% active Retinol, Hyaluronic Acid, Vit...  2134.00        Bad
#
# [27468 rows x 5 columns]

# %%
# For categorical data
print(df_copy['Category'].value_counts())
# Out:
# Category
# Skin          13719
# Grocery        7370
# Hair           2267
# Fragrance      1972
# Bath           1963
# Detergents      177
# Name: count, dtype: int64

# %%
# Replace commas in the 'Category' column
# df['Category'] = df['Category'].str.replace(',', '')
# make bar plot of the categories
df_copy['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
df['Name Length'] = df['Product Title'].apply(len)
print(df[['Product Title', 'Name Length']])

description = df['Name Length'].describe()
print(description)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['Name Length'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Product Name Lengths')
plt.xlabel('Length of Product Name')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
#                                            Product Title  Name Length
# 0       Lee posh Lactic Acid 60% Anti ageing Pigmenta...           70
# 1       Branded SLB Works New 1.5mm Titanium 1200 nee...          104
# 2       Generic 1 Pc brand snail eye cream remove dar...          136
# 3       Generic Anti Snoring Snore Stopper Sleep Apne...           89
# 4       Harveys Crunchy & Creame Gourmet Delicacies C...          116
# ...                                                  ...          ...
# 27463   New Day Creams & Moisturizers Pure Nature Soo...          130
# 27464             Dermasolve Psoriasis Body Wash 8.0 Oz            39
# 27465   Pure Organics Skin Lightening Mild Face Scrub...           53
# 27466   Yashus Moisturizing Anti-aging Gold Collagen ...           67
# 27467   Slss Anti Wrinkle Organic Hyaluronic Acid Vit...           94
#
# [27468 rows x 2 columns]
# count    27468.000000
# mean        81.818625
# std         38.159873
# min          6.000000
# 25%         53.000000
# 50%         74.000000
# 75%        104.000000
# max        467.000000
# Name: Name Length, dtype: float64

# %%
pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting spacy
#   Downloading spacy-3.7.4-cp39-cp39-macosx_11_0_arm64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.19.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from spacy) (1.26.4)
# Collecting thinc<8.3.0,>=8.2.2
#   Downloading thinc-8.2.3-cp39-cp39-macosx_11_0_arm64.whl (795 kB)
#      |████████████████████████████████| 795 kB 940 kB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from spacy) (58.0.4)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp39-cp39-macosx_11_0_arm64.whl (26 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp39-cp39-macosx_11_0_arm64.whl (41 kB)
#      |████████████████████████████████| 41 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from spacy) (2.31.0)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp39-cp39-macosx_11_0_arm64.whl (491 kB)
#      |████████████████████████████████| 491 kB 1.7 MB/s eta 0:00:01
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.7.0-py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 1.4 MB/s eta 0:00:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp39-cp39-macosx_11_0_arm64.whl (129 kB)
#      |████████████████████████████████| 129 kB 890 kB/s eta 0:00:01
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting weasel<0.4.0,>=0.1.0
#   Using cached weasel-0.3.4-py3-none-any.whl (50 kB)
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.4-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 1.0 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from spacy) (23.2)
# Requirement already satisfied: jinja2 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from spacy) (3.1.3)
# Collecting tqdm<5.0.0,>=4.38.0
#   Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Collecting pydantic-core==2.18.1
#   Downloading pydantic_core-2.18.1-cp39-cp39-macosx_11_0_arm64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp39-cp39-macosx_11_0_arm64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 838 kB/s eta 0:00:01
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.1.4-py3-none-any.whl (35 kB)
# Collecting click<9.0.0,>=7.1.1
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting cloudpathlib<0.17.0,>=0.7.0
#   Using cached cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/janerhee/Library/Python/3.9/lib/python/site-packages (from jinja2->spacy) (2.1.5)
# Installing collected packages: pydantic-core, catalogue, annotated-types, srsly, pydantic, murmurhash, cymem, click, wasabi, typer, smart-open, preshed, confection, cloudpathlib, blis, weasel, tqdm, thinc, spacy-loggers, spacy-legacy, langcodes, spacy
#   WARNING: The script weasel is installed in '/Users/janerhee/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm is installed in '/Users/janerhee/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script spacy is installed in '/Users/janerhee/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed annotated-types-0.6.0 blis-0.7.11 catalogue-2.0.10 click-8.1.7 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 pydantic-2.7.0 pydantic-core-2.18.1 smart-open-6.4.0 spacy-3.7.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.3 tqdm-4.66.2 typer-0.9.4 wasabi-1.1.2 weasel-0.3.4
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 1.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.1)
# Requirement already satisfied: jinja2 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.1.0)
# Requirement already satisfied: packaging>=20.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/janerhee/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
 #Tokenize product names using SpaCy
import spacy
import string

from tqdm import tqdm
tqdm.pandas()

punctuation = list(string.punctuation)
NLP = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[35], line 9
#       6 tqdm.pandas()
#       8 punctuation = list(string.punctuation)
# ----> 9 NLP = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
#
# File ~/Library/Python/3.9/lib/python/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/spacy/util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df['spacy_tokens'] = df['text'].apply(lambda x: [token.text for token in nlp(x)])

# %%
#Let's get a list of the lemmas to count the frequency of words but remove the punctuation
punctuation = string.punctuation + '—'  # You can add more symbols here as needed

# Process text to lemmatize and remove punctuation and specific symbols
df['tokens'] = df['Product Name'].progress_apply(lambda x: [x.lemma_.lower() for x in NLP(x) if x.lemma_.lower() not in punctuation])
# Out:
# 100%|██████████| 10002/10002 [00:52<00:00, 190.28it/s]

# %%
# Unwind the data on the tokens
df_tokens = (df
                .explode('tokens'))

# %%
df
# Out:
#                                             Product Name Category  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...   Sports
# 1      Electronic Snap Circuits Mini Kits Classpack, ...     Toys
# 2      3Doodler Create Flexy 3D Printing Filament Ref...     Toys
# 3      Guillow Airplane Design Studio with Travel Cas...     Toys
# 4                Woodstock- Collage 500 pc Puzzle - good     Toys
# ...                                                  ...      ...
# 9997   Remedia Publications REM536B Money Activity Bo...     Toys
# 9998   Trends International NFL La Chargers HG - Mobi...     Toys
# 9999   NewPath Learning 10 Piece Science Owls and Owl...   Office
# 10000  Disney Princess Do It Yourself Braid Set - sli...     Toys
# 10001  Hasegawa Ladders Lucano Step Ladder, Orange - ...     Home
#
#       Selling Price                                             tokens
# 0           $237.68  [db, longboards, coreflex, crossbow, 41, bambo...
# 1            $99.95  [electronic, snap, circuits, mini, kits, class...
# 2            $34.99  [3doodler, create, flexy, 3d, printing, filame...
# 3            $28.91  [guillow, airplane, design, studio, with, trav...
# 4            $17.49       [woodstock-, collage, 500, pc, puzzle, good]
# ...             ...                                                ...
# 9997          $9.31  [remedia, publications, rem536b, money, activi...
# 9998          $6.99  [trend, international, nfl, la, chargers, hg, ...
# 9999         $37.95  [newpath, learning, 10, piece, science, owls, ...
# 10000         $3.58  [disney, princess, do, it, yourself, braid, se...
# 10001       $152.27  [hasegawa, ladders, lucano, step, ladder, oran...
#
# [10002 rows x 4 columns]

# %%
NLP = spacy.load("en_core_web_sm")
tqdm.pandas()
punctuation = string.punctuation + '—'
def process_text(text):
    tokens = [token.lemma_.lower() for token in NLP(text) if token.lemma_ not in punctuation]
    return tokens

df['tokens'] = df['Product Name'].progress_apply(process_text)
# Out:
# 100%|██████████| 10002/10002 [02:08<00:00, 77.94it/s]

# %%
pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 52.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 53.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 75.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 559.7 kB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 6.9 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.9 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.2 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.2 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.7 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence_transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 sentence_transformers-2.6.1

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1')
product_names = df['Product Title'].values
embeddings = model.encode(product_names, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/318 [00:00<?, ?it/s]

# %%
def recommend(query, product_names, embeddings, top_k=5):
    query_embedding = model.encode([query], show_progress_bar=False)
    similarities = cosine_similarity(query_embedding, embeddings).flatten()
    top_indices = np.argsort(similarities)[::-1][:top_k + 1]

    print("Top recommendations:")
    for index in top_indices[0:]:
        print(f"{product_names[index]} (Score: {similarities[index]:.4f})")

while True:
    user_input = input("Enter a product name to search for recommendations (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    recommend(user_input, product_names, embeddings, top_k=5)
# Out:
# Enter a product name to search for recommendations (or type 'exit' to quit): disney
# Top recommendations:
#  Disney Pixar Finding Dory Bubbly Berry Scented Bubble Bath, 24 fl oz  (Score: 0.4609)
#  Lip Smacker Disney Emoji Lip Balm, Cinderella Bibbity Bobbity Berry, 0.26 Ounce  (Score: 0.3246)
#  Verbier Cartoon Super Soft Cotton Baby Bath Shower Brush Cute Animal Modeling Sponge Powder Rubbing Towel Ball For Baby Children White And Black Pack Of 1  (Score: 0.3186)
#  CARNIVAL Creation Being Trendy Loofah/body sraber  (Score: 0.3163)
#  Wild Earth Exotic Travel Kit  (Score: 0.3099)
#  CHOCOCRAFT, Teddy Day gift idea, 6 Chocolate Gift Box, Gifts for Teddy Day  (Score: 0.3057)
# Enter a product name to search for recommendations (or type 'exit' to quit): kindness
# Top recommendations:
#  Chocholik Friendship Gift Box - Friendship is The Smile of The Heart Chocolate Box for Friends - 20pc  (Score: 0.3357)
#  Chocholik Friendship Gift - Youve Been Kind Love You are My Friend - Dark, Milk, White Chocolate Truffles - 9pc  (Score: 0.3144)
#  I Thank U Gift - 12 Chocolate Gift Box - To Say Thank You  (Score: 0.3091)
#  Chocholik Friendship Gift - Best Friends Forever - 9pc  (Score: 0.3083)
#  Chocholik Friendship Gift - Dont Underestimate Friendship Chocolate Box for Friends - 9 Pc  (Score: 0.3073)
#  Chocholik Friendship Gift - A Caring Friend is Thousand Times Better - Dark, Milk, White Chocolate Truffles - 9pc  (Score: 0.3066)
# Enter a product name to search for recommendations (or type 'exit' to quit): friendship
# Top recommendations:
#  Chocholik Friendship Gift - Best Friends Forever - 9pc  (Score: 0.5738)
#  Chocholik Friendship Gift - I Don۪t Have A Big Group of Friends - 9 Pc  (Score: 0.5627)
#  Chocholik Friendship Gift - The Only Way to Have a Friend is to Be One -20pc  (Score: 0.5481)
#  Chocholik Friendship Gift - Never Lose a True Friend - 12pc  (Score: 0.5341)
#  Chocholik Friendship Gift Box - Friendship is Precious Chocolate Box for Friends - 20pc  (Score: 0.5275)
#  Chocholik Friendship Gift - Dont Underestimate Friendship Chocolate Box for Friends - 9 Pc  (Score: 0.5219)
# Enter a product name to search for recommendations (or type 'exit' to quit): exit

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 27.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.25.2)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0

# %%
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1')
product_names = df['Product Title'].values
embeddings = model.encode(product_names, show_progress_bar=True).astype('float32')
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)
# Out:
# Batches:   0%|          | 0/318 [00:00<?, ?it/s]

# %%
def recommend(query, index, product_names, top_k=5):
    query_embedding = model.encode([query], show_progress_bar=False).astype('float32')
    query_embedding = query_embedding.reshape(1, -1)
    distances, indices = index.search(query_embedding, top_k + 1)
    print("Top recommendations:")
    for i, idx in enumerate(indices[0][0:]):
        print(f"{i + 1}: {product_names[idx]} (Score: {1 - distances[0][i]})")

while True:
    user_input = input("Enter a product name to search for recommendations (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':₩
        break
    recommend(user_input, index, product_names, top_k=5)
# Out:
# Enter a product name to search for recommendations (or type 'exit' to quit): disney
# Top recommendations:
# 1:  Disney Pixar Finding Dory Bubbly Berry Scented Bubble Bath, 24 fl oz  (Score: -0.07822108268737793)
# 2:  Lip Smacker Disney Emoji Lip Balm, Cinderella Bibbity Bobbity Berry, 0.26 Ounce  (Score: -0.3508031368255615)
# 3:  Verbier Cartoon Super Soft Cotton Baby Bath Shower Brush Cute Animal Modeling Sponge Powder Rubbing Towel Ball For Baby Children White And Black Pack Of 1  (Score: -0.3627660274505615)
# 4:  CARNIVAL Creation Being Trendy Loofah/body sraber  (Score: -0.3674302101135254)
# 5:  Wild Earth Exotic Travel Kit  (Score: -0.38028430938720703)
# 6:  CHOCOCRAFT, Teddy Day gift idea, 6 Chocolate Gift Box, Gifts for Teddy Day  (Score: -0.38856661319732666)
# Enter a product name to search for recommendations (or type 'exit' to quit): exit
